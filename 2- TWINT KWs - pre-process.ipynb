# %% [markdown]
# # Parse results

# %% [markdown]
# ## Imports

# %%
import boto3
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Utils

# %%
def endswith_backslash(str1):
  return str1.endswith("/")

def get_dirlist_s3(prefix: str,
                   client=boto3.client('s3'),
                   bucket='REDACTED'):
  """
  args:
      client: boto3 client (s3)
      bucket (str): name of bucket
      prefix (str): path without bucket (endswith backslash)
  """
  if not endswith_backslash(prefix):
    raise ValueError("prefix must end with backslash")
  return client.list_objects(Bucket=bucket, Prefix=prefix, Delimiter='/')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
file_names = []
dates = ["2022-01-23", "2022-01-25", "2022-02-01", "2022-02-03", "2022-02-06", "2022-02-08", "2022-02-09", "2022-02-10", "2022-02-13", "2022-02-14", "2022-02-15", "2022-02-16", "2022-02-18"]
for date in dates:
  raw_data = get_dirlist_s3(f'orbl/twint/amazon/dt={date}/')
  temp_file_names = ["s3://REDACTED/" + dct["Key"] for dct in raw_data["Contents"]]
  file_names += temp_file_names
file_names[:5]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: [&#39;s3://activefence-user/orbl/twint/amazon/dt=2022-01-23/amazon_app.csv&#39;,
#  &#39;s3://activefence-user/orbl/twint/amazon/dt=2022-01-23/amazon_application.csv&#39;,
#  &#39;s3://activefence-user/orbl/twint/amazon/dt=2022-01-23/amazon_site.csv&#39;,
#  &#39;s3://activefence-user/orbl/twint/amazon/dt=2022-01-23/amazon_website.csv&#39;,
#  &#39;s3://activefence-user/orbl/twint/amazon/dt=2022-01-23/exact_amazon_app.csv&#39;]</div>

# %%
df = pd.read_csv(file_names[0])
for path in file_names[1:]:
  temp_df = pd.read_csv(path)
  df = pd.concat([df, temp_df], axis=0)
df = df.drop_duplicates()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Filter out anomalies
# * by modified_date
# * by # tweets above threshold

# %%
TWEETS_THRESHOLD = 10
df["modified_date"] = df.date.apply(lambda date: date[:10])
count_df = df\
  .groupby(["type", "modified_date"]).size()\
  .reset_index()\
  .rename(columns={0: "count"})
count_df = count_df[(count_df["count"] > TWEETS_THRESHOLD) & 
                   (count_df["modified_date"] != "2022-01-13") & 
                   (count_df["modified_date"] != "2022-01-14") & 
                   (count_df["modified_date"] != "2022-02-18") & 
                   (count_df["modified_date"] != "2022-02-19")]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
tweets_df = df\
    .merge(count_df, 
           on="modified_date", 
           how="inner")\
   .rename(columns={'type_x': "type"})[df.columns]
tweets_df.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>conversation_id</th>
#       <th>created_at</th>
#       <th>date</th>
#       <th>timezone</th>
#       <th>place</th>
#       <th>tweet</th>
#       <th>language</th>
#       <th>hashtags</th>
#       <th>cashtags</th>
#       <th>user_id</th>
#       <th>user_id_str</th>
#       <th>username</th>
#       <th>name</th>
#       <th>day</th>
#       <th>hour</th>
#       <th>link</th>
#       <th>urls</th>
#       <th>photos</th>
#       <th>video</th>
#       <th>thumbnail</th>
#       <th>retweet</th>
#       <th>nlikes</th>
#       <th>nreplies</th>
#       <th>nretweets</th>
#       <th>quote_url</th>
#       <th>search</th>
#       <th>near</th>
#       <th>geo</th>
#       <th>source</th>
#       <th>user_rt_id</th>
#       <th>user_rt</th>
#       <th>retweet_id</th>
#       <th>reply_to</th>
#       <th>retweet_date</th>
#       <th>translate</th>
#       <th>trans_src</th>
#       <th>trans_dest</th>
#       <th>query</th>
#       <th>type</th>
#       <th>modified_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1485344539074301957</td>
#       <td>1485342419159855109</td>
#       <td>1.642969e+12</td>
#       <td>2022-01-23 20:11:49</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>@spikepoint The one thing I hate about Amazon ...</td>
#       <td>en</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>1269508676823519233</td>
#       <td>1269508676823519233</td>
#       <td>suburbancoyotee</td>
#       <td>theresa!</td>
#       <td>7</td>
#       <td>20</td>
#       <td>https://twitter.com/suburbancoyotee/status/148...</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>amazon app</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>[{'screen_name': 'spikepoint', 'name': 'Capt. ...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>amazon app</td>
#       <td>application</td>
#       <td>2022-01-23</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1485344539074301957</td>
#       <td>1485342419159855109</td>
#       <td>1.642969e+12</td>
#       <td>2022-01-23 20:11:49</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>@spikepoint The one thing I hate about Amazon ...</td>
#       <td>en</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>1269508676823519233</td>
#       <td>1269508676823519233</td>
#       <td>suburbancoyotee</td>
#       <td>theresa!</td>
#       <td>7</td>
#       <td>20</td>
#       <td>https://twitter.com/suburbancoyotee/status/148...</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>amazon app</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>[{'screen_name': 'spikepoint', 'name': 'Capt. ...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>amazon app</td>
#       <td>application</td>
#       <td>2022-01-23</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1485343775241158662</td>
#       <td>1481322928662884364</td>
#       <td>1.642969e+12</td>
#       <td>2022-01-23 20:08:47</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>@graanhay Para que podamos guiarte de la mejor...</td>
#       <td>es</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>85741735</td>
#       <td>85741735</td>
#       <td>AmazonHelp</td>
#       <td>Amazon Help</td>
#       <td>7</td>
#       <td>20</td>
#       <td>https://twitter.com/AmazonHelp/status/14853437...</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>amazon app</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>[{'screen_name': 'graanhay', 'name': 'Gra 🇦🇷🇦🇷...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>amazon app</td>
#       <td>application</td>
#       <td>2022-01-23</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1485343775241158662</td>
#       <td>1481322928662884364</td>
#       <td>1.642969e+12</td>
#       <td>2022-01-23 20:08:47</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>@graanhay Para que podamos guiarte de la mejor...</td>
#       <td>es</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>85741735</td>
#       <td>85741735</td>
#       <td>AmazonHelp</td>
#       <td>Amazon Help</td>
#       <td>7</td>
#       <td>20</td>
#       <td>https://twitter.com/AmazonHelp/status/14853437...</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>amazon app</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>[{'screen_name': 'graanhay', 'name': 'Gra 🇦🇷🇦🇷...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>amazon app</td>
#       <td>application</td>
#       <td>2022-01-23</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1485343321883090949</td>
#       <td>1481322928662884364</td>
#       <td>1.642968e+12</td>
#       <td>2022-01-23 20:06:58</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>@AmazonHelp La app está en el servicio de Tele...</td>
#       <td>es</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>1427811495048617989</td>
#       <td>1427811495048617989</td>
#       <td>graanhay</td>
#       <td>Gra 🇦🇷🇦🇷</td>
#       <td>7</td>
#       <td>20</td>
#       <td>https://twitter.com/graanhay/status/1485343321...</td>
#       <td>[]</td>
#       <td>[]</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>amazon app</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>[{'screen_name': 'AmazonHelp', 'name': 'Amazon...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>amazon app</td>
#       <td>application</td>
#       <td>2022-01-23</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import datetime
today = datetime.datetime.today().strftime("%Y-%m-%d")
path = f"s3://REDACTED/orbl/twint/amazon/processed_not_labeled/dt={today}/tweets.csv"
tweets_df.to_csv(path, index=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
tweets_df.tweet.iloc[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: &#34;@spikepoint The one thing I hate about Amazon music is that they don&#39;t stream their Atmos music through TVs like tidal does but it&#39;s also the least expensive way to get spacial audio remixes of music so you win some lose some  Also their app is HORRIBLE. Albums will just randomly miss songs&#34;</div>
